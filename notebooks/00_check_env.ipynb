# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

print("Interpreter :", sys.executable)
print("pandas      :", pd.__version__)
print("numpy       :", np.__version__)
print("scikit-learn:", sklearn.__version__)

sns.set_theme()
plt.plot([1, 2, 3], [2, 4, 9], marker="o")
plt.title("Environment OK")
plt.show()
# Out:
# Interpreter : c:\Users\Lenovo LOQ\Desktop\PFA_2026\intelligent-helpdesk-api\.venv\Scripts\python.exe
# pandas      : 3.0.5
# numpy       : 2.5.1
# scikit-learn: 1.9.0
